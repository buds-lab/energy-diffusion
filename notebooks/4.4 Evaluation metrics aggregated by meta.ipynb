# %%
# !pip install scipy==1.11.1
# Out:
# Collecting scipy==1.11.1
#   Downloading scipy-1.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy==1.11.1) (1.25.2)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
# Successfully installed scipy-1.11.1

# %%
from keras.layers import Input, Dense, Conv2D, Flatten, Reshape, Conv2DTranspose
from keras.models import Model
from keras.datasets import mnist
from keras.utils import to_categorical
from keras import backend as K
from keras.callbacks import Callback
import tensorflow as tf

from scipy.stats import entropy
from scipy.linalg import sqrtm
from scipy.stats import pearsonr

from keras.applications.inception_v3 import InceptionV3

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.models import load_model

import cv2

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy.stats import entropy
from scipy.spatial.distance import cosine

import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from scipy.linalg import sqrtm

from tqdm import tqdm

# %%
import random

seed = 42

# Python's built-in random library
random.seed(seed)

# Scikit-learn (only affects some parts of scikit-learn)
from sklearn.utils import check_random_state
check_random_state(seed)

np.random.seed(seed)
tf.random.set_seed(seed)
tf.keras.utils.set_random_seed(seed)

# %%
img_rows = 168
img_cols = 168
channels = 1

# Input image dimensions
img_shape = (img_rows, img_cols, channels)

# %%
# Set path for data source
import os
from google.colab import drive
drive.mount('/content/gdrive')
os.chdir("/content/gdrive/My Drive/Load Diffusion/dataset/")
# Out:
# Mounted at /content/gdrive

# %%
# Set the path to the folder containing saved files
load_path = "./preprocessed_data_168x168_2years"

# Load saved NumPy arrays
X_train = np.load(os.path.join(load_path, 'X_train.npy'))
X_test = np.load(os.path.join(load_path, 'X_test.npy'))
y_train = np.load(os.path.join(load_path, 'y_train.npy'))
y_test = np.load(os.path.join(load_path, 'y_test.npy'))

# Load saved Pandas DataFrames
train_data = pd.read_pickle(os.path.join(load_path, 'train_data.pkl'))
test_data = pd.read_pickle(os.path.join(load_path, 'test_data.pkl'))
metadata = pd.read_pickle(os.path.join(load_path, 'metadata.pkl'))
metadata_original = pd.read_pickle(os.path.join(load_path, 'metadata_original.pkl'))

# %%
def merge_dummified_columns(df, dummified_columns, new_column_name):
    """
    Merges dummified columns into a single column in a DataFrame.

    Parameters:
        df (pd.DataFrame): The DataFrame containing the dummified columns.
        dummified_columns (list): A list of the names of the dummified columns.
        new_column_name (str): The name of the new column to create.

    Returns:
        pd.DataFrame: The DataFrame with the dummified columns merged into a single new column.
    """
    # Create a new column containing the column name where the value is 1 for each row
    df[new_column_name] = df[dummified_columns].idxmax(axis=1)

    # Drop the dummified columns
    df.drop(dummified_columns, axis=1, inplace=True)

    return df

test_metadata = metadata_original.loc[test_data.columns]

test_metadata = merge_dummified_columns(test_metadata,
                     dummified_columns=['chilledwater', 'electricity', 'gas', 'hotwater', 'steam'],
                     new_column_name='meter_type')
test_metadata = merge_dummified_columns(test_metadata,
                     dummified_columns=['Education', 'Entertainment/public assembly', 'Lodging/residential', 'Office', 'Public services'],
                     new_column_name='building_type')

test_metadata
# Out:
#                                               lat         lng  year  \
# electricity_Lamb_office_Caitlin_2016    51.497838   -3.186246  2016
# electricity_Rat_public_Kelle_2016       38.903504  -77.005349  2016
# electricity_Rat_assembly_Ezequiel_2016  38.903504  -77.005349  2016
# electricity_Bear_assembly_Roxy_2016     37.871903 -122.260729  2016
# gas_Shrew_office_Rose_2017              51.499840   -0.124663  2017
# ...                                           ...         ...   ...
# steam_Moose_education_Omar_2016         45.421500  -75.697200  2016
# electricity_Rat_public_Chrissy_2017     38.903504  -77.005349  2017
# electricity_Hog_office_Merilyn_2016     44.978782  -93.255398  2016
# steam_Bull_assembly_Amalia_2016         30.267200  -97.743100  2016
# electricity_Rat_office_Jeannie_2017     38.903504  -77.005349  2017
#
#                                          meter_type  \
# electricity_Lamb_office_Caitlin_2016    electricity
# electricity_Rat_public_Kelle_2016       electricity
# electricity_Rat_assembly_Ezequiel_2016  electricity
# electricity_Bear_assembly_Roxy_2016     electricity
# gas_Shrew_office_Rose_2017                      gas
# ...                                             ...
# steam_Moose_education_Omar_2016               steam
# electricity_Rat_public_Chrissy_2017     electricity
# electricity_Hog_office_Merilyn_2016     electricity
# steam_Bull_assembly_Amalia_2016               steam
# electricity_Rat_office_Jeannie_2017     electricity
#
#                                                         building_type
# electricity_Lamb_office_Caitlin_2016                           Office
# electricity_Rat_public_Kelle_2016                     Public services
# electricity_Rat_assembly_Ezequiel_2016  Entertainment/public assembly
# electricity_Bear_assembly_Roxy_2016     Entertainment/public assembly
# gas_Shrew_office_Rose_2017                                     Office
# ...                                                               ...
# steam_Moose_education_Omar_2016                             Education
# electricity_Rat_public_Chrissy_2017                   Public services
# electricity_Hog_office_Merilyn_2016                            Office
# steam_Bull_assembly_Amalia_2016         Entertainment/public assembly
# electricity_Rat_office_Jeannie_2017                            Office
#
# [901 rows x 5 columns]

# %%
def calculate_rmse(true_data, predicted_data):
    return np.sqrt(mean_squared_error(true_data, predicted_data))

def calculate_mae(true_data, predicted_data):
    return mean_absolute_error(true_data, predicted_data)

def calculate_r2(true_data, predicted_data):
    return r2_score(true_data, predicted_data)

def calculate_kl_divergence(true_data, predicted_data):
    return entropy(true_data+0.00000001, predicted_data+0.00000001)

def calculate_cosine_similarity(true_data, predicted_data):
    return 1 - cosine(true_data, predicted_data)

# %%
def evaluate_model(test_data, generated_series):
    metrics_result = {
        'rmse': [],
        'mae': [],
        'r2': [],
        'kl_divergence': [],
        'cosine_similarity': [],
        'pearson_correlation': []
    }

    for i in range(test_data.shape[1]):
        try:
            true_data = test_data[:, i]
            predicted_data = generated_series[:, i]
        except:
            true_data = test_data.values[:, i]
            predicted_data = generated_series.values[:, i]

        # Calculate Pearson correlation
        pearson_corr, _ = pearsonr(true_data, predicted_data)

        metrics_result['rmse'].append(calculate_rmse(true_data, predicted_data))
        metrics_result['mae'].append(calculate_mae(true_data, predicted_data))
        metrics_result['r2'].append(calculate_r2(true_data, predicted_data))
        metrics_result['kl_divergence'].append(calculate_kl_divergence(true_data, predicted_data))
        metrics_result['cosine_similarity'].append(calculate_cosine_similarity(true_data, predicted_data))
        metrics_result['pearson_correlation'].append(pearson_corr)

    return metrics_result

# Function to calculate FID between two sets of images
def calculate_fid(model, images1, images2):
    # Calculate activations
    act1 = model.predict(images1)
    act2 = model.predict(images2)

    # Calculate mean and covariance statistics
    mu1, sigma1 = act1.mean(axis=0), np.cov(act1, rowvar=False)
    mu2, sigma2 = act2.mean(axis=0), np.cov(act2, rowvar=False)

    # Calculate sum squared difference between means
    ssdiff = np.sum((mu1 - mu2)**2.0)

    # Calculate sqrt of product between covariances
    covmean = sqrtm(sigma1.dot(sigma2))

    # Check and correct imaginary numbers from sqrt
    if np.iscomplexobj(covmean):
        covmean = covmean.real

    # Calculate the FID score
    fid = ssdiff + np.trace(sigma1 + sigma2 - 2.0 * covmean)
    return fid

# %%
test_metadata.pivot_table(index=['lat'],aggfunc='count')
# Out:
#            building_type  lng  meter_type  year
# lat
# 28.517689              9    9           9     9
# 30.267200            143  143         143   143
# 33.424425            144  144         144   144
# 37.406733            115  115         115   115
# 37.871903             27   27          27    27
# 38.903504            135  135         135   135
# 40.350000             24   24          24    24
# 44.978782            135  135         135   135
# 45.421500             18   18          18    18
# 51.497838             90   90          90    90
# 51.499840              5    5           5     5
# 51.518790             33   33          33    33
# 53.349800             23   23          23    23

# %%
test_metadata.pivot_table(index=['building_type'],aggfunc='count')
# Out:
#                                lat  lng  meter_type  year
# building_type
# Education                      404  404         404   404
# Entertainment/public assembly  115  115         115   115
# Lodging/residential             94   94          94    94
# Office                         212  212         212   212
# Public services                 76   76          76    76

# %%
test_metadata.pivot_table(index=['meter_type'],aggfunc='count')
# Out:
#               building_type  lat  lng  year
# meter_type
# chilledwater            199  199  199   199
# electricity             447  447  447   447
# gas                      75   75   75    75
# hotwater                 68   68   68    68
# steam                   112  112  112   112

# %%
agg_col_list = ['lat', 'building_type', 'meter_type']

# Initialize an empty DataFrame to store metrics
df_metrics = []

# %%
test_data = (test_data+1)/2

# %%
test_data.shape
# Out:
# (8736, 901)

# %%
test_data.describe()
# Out:
#        electricity_Lamb_office_Caitlin_2016  \
# count                           8736.000000
# mean                               0.188451
# std                                0.237092
# min                                0.000000
# 25%                                0.043682
# 50%                                0.069787
# 75%                                0.219570
# max                                1.000000
#
#        electricity_Rat_public_Kelle_2016  \
# count                        8736.000000
# mean                            0.348453
# std                             0.173016
# min                             0.000000
# 25%                             0.206243
# 50%                             0.337544
# 75%                             0.438935
# max                             1.000000
#
#        electricity_Rat_assembly_Ezequiel_2016  \
# count                             8736.000000
# mean                                 0.258079
# std                                  0.202699
# min                                  0.000000
# 25%                                  0.100734
# 50%                                  0.201469
# 75%                                  0.355357
# max                                  1.000000
#
#        electricity_Bear_assembly_Roxy_2016  gas_Shrew_office_Rose_2017  \
# count                          8736.000000                 8736.000000
# mean                              0.173391                    0.091892
# std                               0.193813                    0.207332
# min                               0.000000                    0.000000
# 25%                               0.057022                    0.000000
# 50%                               0.092661                    0.000000
# 75%                               0.206706                    0.000000
# max                               1.000000                    1.000000
#
#        electricity_Lamb_assembly_Cherie_2017  \
# count                            8736.000000
# mean                                0.250770
# std                                 0.306181
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000353
# 75%                                 0.510895
# max                                 1.000000
#
#        electricity_Rat_education_Nellie_2017  \
# count                            8736.000000
# mean                                0.337465
# std                                 0.210603
# min                                 0.000000
# 25%                                 0.177187
# 50%                                 0.247577
# 75%                                 0.446030
# max                                 1.000000
#
#        chilledwater_Bull_education_Miquel_2017  \
# count                              8736.000000
# mean                                  0.395970
# std                                   0.247460
# min                                   0.000000
# 25%                                   0.180456
# 50%                                   0.386270
# 75%                                   0.607443
# max                                   1.000000
#
#        hotwater_Fox_lodging_Stephen_2016  \
# count                        8736.000000
# mean                            0.162933
# std                             0.256923
# min                             0.000000
# 25%                             0.000000
# 50%                             0.076923
# 75%                             0.153846
# max                             1.000000
#
#        electricity_Rat_assembly_Damaris_2017  ...  \
# count                            8736.000000  ...
# mean                                0.294121  ...
# std                                 0.231476  ...
# min                                 0.000000  ...
# 25%                                 0.118665  ...
# 50%                                 0.208900  ...
# 75%                                 0.423980  ...
# max                                 1.000000  ...
#
#        chilledwater_Moose_education_Abbie_2017  \
# count                              8736.000000
# mean                                  0.170633
# std                                   0.214950
# min                                   0.000000
# 25%                                   0.023933
# 50%                                   0.057400
# 75%                                   0.293706
# max                                   1.000000
#
#        electricity_Eagle_education_Teresa_2017  \
# count                              8736.000000
# mean                                  0.428276
# std                                   0.171506
# min                                   0.000000
# 25%                                   0.306398
# 50%                                   0.418361
# 75%                                   0.533525
# max                                   1.000000
#
#        chilledwater_Hog_public_Crystal_2016  steam_Hog_office_Garrett_2016  \
# count                           8736.000000                    8736.000000
# mean                               0.243286                       0.215425
# std                                0.352709                       0.244234
# min                                0.000000                       0.000000
# 25%                                0.000000                       0.005794
# 50%                                0.000000                       0.132097
# 75%                                0.597015                       0.348783
# max                                1.000000                       1.000000
#
#        electricity_Lamb_assembly_Elinor_2017  steam_Moose_education_Omar_2016  \
# count                            8736.000000                      8736.000000
# mean                                0.137308                         0.291646
# std                                 0.209695                         0.280920
# min                                 0.000000                         0.000000
# 25%                                 0.000000                         0.023153
# 50%                                 0.000377                         0.244535
# 75%                                 0.247070                         0.565617
# max                                 1.000000                         1.000000
#
#        electricity_Rat_public_Chrissy_2017  \
# count                          8736.000000
# mean                              0.330380
# std                               0.155869
# min                               0.000000
# 25%                               0.209051
# 50%                               0.301679
# 75%                               0.437118
# max                               1.000000
#
#        electricity_Hog_office_Merilyn_2016  steam_Bull_assembly_Amalia_2016  \
# count                          8736.000000                      8736.000000
# mean                              0.420632                         0.373292
# std                               0.170919                         0.160209
# min                               0.000000                         0.000000
# 25%                               0.258872                         0.265928
# 50%                               0.447640                         0.362881
# 75%                               0.552548                         0.462604
# max                               1.000000                         1.000000
#
#        electricity_Rat_office_Jeannie_2017
# count                          8736.000000
# mean                              0.401658
# std                               0.183267
# min                               0.000000
# 25%                               0.281406
# 50%                               0.374426
# 75%                               0.507801
# max                               1.000000
#
# [8 rows x 901 columns]

# %%
model_name = 'CVAE_mse'
generation_path = "./generation/" + model_name + '_168x168'

file_name = os.listdir(generation_path)[2]

# Load the dataset
generated_images = np.load(os.path.join(generation_path, file_name))

print(generated_images.shape)
print(generated_images.max())
print(generated_images.min())
# Out:
# (901, 168, 168, 1)
# 0.86604565
# 0.001584873

# %%
model_name = 'CGAN'
generation_path = "./generation/" + model_name + '_168x168'

file_name = os.listdir(generation_path)[0]

# Load the dataset
generated_images = np.load(os.path.join(generation_path, file_name))

print(generated_images.shape)
print(generated_images.max())
print(generated_images.min())
# Out:
# (901, 168, 168, 1)
# 0.99997425
# 0.0

# %%
model_name = 'diffusion_model'
generation_path = "./generation/" + model_name + '_168x168'

file_name = os.listdir(generation_path)[0]

# Load the dataset
generated_images = np.load(os.path.join(generation_path, file_name))

print(generated_images.shape)
print(generated_images.max())
print(generated_images.min())
# Out:
# (901, 168, 168, 1)
# 1.4020152
# -0.16470277

# %%
test_data.max()
# Out:
# electricity_Lamb_office_Caitlin_2016      1.0
# electricity_Rat_public_Kelle_2016         1.0
# electricity_Rat_assembly_Ezequiel_2016    1.0
# electricity_Bear_assembly_Roxy_2016       1.0
# gas_Shrew_office_Rose_2017                1.0
#                                          ...
# steam_Moose_education_Omar_2016           1.0
# electricity_Rat_public_Chrissy_2017       1.0
# electricity_Hog_office_Merilyn_2016       1.0
# steam_Bull_assembly_Amalia_2016           1.0
# electricity_Rat_office_Jeannie_2017       1.0
# Length: 901, dtype: float64

# %%
for model_name in ['CVAE_mse','CGAN','diffusion_model']:

  generation_path = "./generation/" + model_name + '_168x168'

  file_name = os.listdir(generation_path)[0]

  # Load the dataset
  generated_images = np.load(os.path.join(generation_path, file_name))

  #generated_images = (generated_images - generated_images.min())/(generated_images.max() - generated_images.min())

  # Set the target shape
  target_shape = (generated_images.shape[0], 52, 168, 1)

  # Initialize an array to hold the resized images
  resized_images = np.zeros(target_shape)

  # Loop through each image to resize it
  for i in range(generated_images.shape[0]):
      resized_image = cv2.resize(generated_images[i], (168, 52))  # Note the dimensions are (width, height)
      resized_images[i] = np.expand_dims(resized_image, axis=-1)  # Add back the last dimension

  # Assume resized_images has a shape of (generated_images.shape[0], 52, 168, 1)
  flattened_images = resized_images.reshape(generated_images.shape[0], -1).T  # Transpose to get shape (8736, generated_images.shape[0])

  generated_series = pd.DataFrame(flattened_images)
  generated_series.columns = test_data.columns

  generated_series = (generated_series-generated_series.min())/(generated_series.max()-generated_series.min())
  test_data = (test_data-test_data.min())/(test_data.max()-test_data.min())

  test_data_resampled = test_data.rolling(24).mean()[23::24]
  generated_series_resampled = generated_series.rolling(24).mean()[23::24]

  # Prepare the Inception v3 model
  model = InceptionV3(include_top=False, pooling='avg', weights="imagenet", input_shape=(99,99,3))

  # Convert to RGB and upscale to the necessary input size for the Inception model
  X_test_rgb = tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_test))
  generated_images_rgb = tf.image.grayscale_to_rgb(tf.convert_to_tensor(generated_images))

  X_test_upscaled = tf.image.resize(X_test_rgb, [99, 99])
  generated_images_upscaled = tf.image.resize(generated_images_rgb, [99, 99])

  for agg_col in agg_col_list:

    agg_items = test_metadata[agg_col].unique()
    for agg_item in agg_items:
      print(agg_item)

      filtered_meters = test_metadata[test_metadata[agg_col]==agg_item].index

      test_data_subset = test_data[filtered_meters]
      generated_series_subset = generated_series[filtered_meters]

      X_test_upscaled_subset = X_test_upscaled[(test_metadata[agg_col]==agg_item).values]
      generated_images_upscaled_subset = generated_images_upscaled[(test_metadata[agg_col]==agg_item).values]

      evaluation_results = evaluate_model(test_data_subset, generated_series_subset)
      df_evaluation_results = pd.DataFrame(evaluation_results)

      # Calculate FID
      fid_score = calculate_fid(model, X_test_upscaled_subset, generated_images_upscaled_subset)
      #print('FID: '+str(fid_score))

      metrics = df_evaluation_results.mean()
      metrics['fid_score'] = fid_score
      metrics['model'] = model_name
      metrics['agg_col'] = agg_col
      metrics['agg_item'] = agg_item
      metrics = metrics.to_frame().T
      print(metrics.to_dict())

      # Append the metrics to df_metrics
      df_metrics.append(metrics)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# 51.49783804108846
# 3/3 [==============================] - 3s 377ms/step
# 3/3 [==============================] - 1s 369ms/step
# {'rmse': {0: 0.28107568269281613}, 'mae': {0: 0.22951228222241957}, 'r2': {0: -1.2914098367938216}, 'kl_divergence': {0: 0.8051318919814264}, 'cosine_similarity': {0: 0.6654347914513583}, 'pearson_correlation': {0: 0.4511816970589398}, 'fid_score': {0: 2239.6571797366596}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 51.49783804108846}}
# 38.9035039800032
# 5/5 [==============================] - 2s 346ms/step
# 5/5 [==============================] - 2s 324ms/step
# {'rmse': {0: 0.24360670144451485}, 'mae': {0: 0.19422586761006863}, 'r2': {0: -0.8464013610939257}, 'kl_divergence': {0: 0.2859243179565129}, 'cosine_similarity': {0: 0.8128212306825693}, 'pearson_correlation': {0: 0.32023428442476515}, 'fid_score': {0: 1130.7965045206238}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 38.9035039800032}}
# 37.87190340000004
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 361ms/step
# {'rmse': {0: 0.22446623159094295}, 'mae': {0: 0.18143733190147182}, 'r2': {0: -0.4842012928427349}, 'kl_divergence': {0: 0.22543691493508206}, 'cosine_similarity': {0: 0.8553480127290217}, 'pearson_correlation': {0: 0.513793957727811}, 'fid_score': {0: 1423.3624471430871}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 37.87190340000004}}
# 51.49984
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 161ms/step
# {'rmse': {0: 0.31108310073763823}, 'mae': {0: 0.2637647627455799}, 'r2': {0: -0.7803676849389126}, 'kl_divergence': {0: 1.0055914611149261}, 'cosine_similarity': {0: 0.6188272950558209}, 'pearson_correlation': {0: 0.27167625579485255}, 'fid_score': {0: 4184.534050025277}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 51.49984}}
# 30.26719999999989
# 5/5 [==============================] - 2s 348ms/step
# 5/5 [==============================] - 3s 607ms/step
# {'rmse': {0: 0.23833287169321762}, 'mae': {0: 0.1940049777994193}, 'r2': {0: -0.7999443807737878}, 'kl_divergence': {0: 0.29036564885280525}, 'cosine_similarity': {0: 0.8221177085913215}, 'pearson_correlation': {0: 0.34490452458808746}, 'fid_score': {0: 1135.1842881587058}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 30.26719999999989}}
# 33.42442530000004
# 5/5 [==============================] - 2s 347ms/step
# 5/5 [==============================] - 2s 355ms/step
# {'rmse': {0: 0.27108241290060764}, 'mae': {0: 0.22452538255337673}, 'r2': {0: -15.130317231449611}, 'kl_divergence': {0: 0.5439965042798627}, 'cosine_similarity': {0: 0.7560660493946173}, 'pearson_correlation': {0: 0.30821648916588085}, 'fid_score': {0: 1178.6216455813114}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 33.42442530000004}}
# 44.97878184783975
# 5/5 [==============================] - 2s 325ms/step
# 5/5 [==============================] - 2s 321ms/step
# {'rmse': {0: 0.25938661498658916}, 'mae': {0: 0.2121948791275173}, 'r2': {0: -0.4942860115136699}, 'kl_divergence': {0: 0.5097040046529286}, 'cosine_similarity': {0: 0.7574027365210795}, 'pearson_correlation': {0: 0.435488856077694}, 'fid_score': {0: 1044.6591689604616}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 44.97878184783975}}
# 37.406733422173815
# 4/4 [==============================] - 1s 344ms/step
# 4/4 [==============================] - 1s 347ms/step
# {'rmse': {0: 0.2800667860131559}, 'mae': {0: 0.22882261299162437}, 'r2': {0: -1.1593089519842608}, 'kl_divergence': {0: 0.4302253777096943}, 'cosine_similarity': {0: 0.7555541458431335}, 'pearson_correlation': {0: 0.194768864324511}, 'fid_score': {0: 1162.2510585542523}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 37.406733422173815}}
# 45.4215
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 251ms/step
# {'rmse': {0: 0.28287841416013276}, 'mae': {0: 0.2350967033750416}, 'r2': {0: -0.6477954210265862}, 'kl_divergence': {0: 0.5464500224958598}, 'cosine_similarity': {0: 0.728729799602888}, 'pearson_correlation': {0: 0.3339143353310434}, 'fid_score': {0: 1590.586445546287}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 45.4215}}
# 53.34979999999997
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 303ms/step
# {'rmse': {0: 0.2550874397032442}, 'mae': {0: 0.20562345126895873}, 'r2': {0: -0.5475957689070119}, 'kl_divergence': {0: 0.5205886099361197}, 'cosine_similarity': {0: 0.764584456026624}, 'pearson_correlation': {0: 0.4546751066082063}, 'fid_score': {0: 1738.2583934841261}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 53.34979999999997}}
# 51.51878965384613
# 2/2 [==============================] - 1s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# {'rmse': {0: 0.22806741079024628}, 'mae': {0: 0.1860221986157135}, 'r2': {0: -0.6920429913604547}, 'kl_divergence': {0: 0.26828299309204}, 'cosine_similarity': {0: 0.8436731530523776}, 'pearson_correlation': {0: 0.4122439676899726}, 'fid_score': {0: 1272.3326505653977}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 51.51878965384613}}
# 40.349999999999966
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 309ms/step
# {'rmse': {0: 0.239270736884352}, 'mae': {0: 0.1943493622732229}, 'r2': {0: -32.26699180959178}, 'kl_divergence': {0: 0.6677261860123024}, 'cosine_similarity': {0: 0.7883168978353146}, 'pearson_correlation': {0: 0.43751717198327444}, 'fid_score': {0: 1483.8894312148377}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 40.349999999999966}}
# 28.5176885788321
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 252ms/step
# {'rmse': {0: 0.2787176435430029}, 'mae': {0: 0.22534746416462292}, 'r2': {0: -1.5827670269846867}, 'kl_divergence': {0: 0.3835735925037239}, 'cosine_similarity': {0: 0.7806939585212975}, 'pearson_correlation': {0: 0.2265463921247484}, 'fid_score': {0: 2400.299879333125}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 28.5176885788321}}
# Office
# 7/7 [==============================] - 4s 543ms/step
# 7/7 [==============================] - 3s 380ms/step
# {'rmse': {0: 0.2561800716970727}, 'mae': {0: 0.20925903472861845}, 'r2': {0: -0.6990230444812513}, 'kl_divergence': {0: 0.45470930638114004}, 'cosine_similarity': {0: 0.7755303862729934}, 'pearson_correlation': {0: 0.4002081127837339}, 'fid_score': {0: 1092.9021477903102}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Office'}}
# Public services
# 3/3 [==============================] - 1s 278ms/step
# 3/3 [==============================] - 1s 276ms/step
# {'rmse': {0: 0.25180353333360034}, 'mae': {0: 0.20529562526951547}, 'r2': {0: -0.7767974014321318}, 'kl_divergence': {0: 0.29673457984838447}, 'cosine_similarity': {0: 0.8140882728347596}, 'pearson_correlation': {0: 0.3011268407146765}, 'fid_score': {0: 1246.4820804775848}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Public services'}}
# Entertainment/public assembly
# 4/4 [==============================] - 1s 353ms/step
# 4/4 [==============================] - 1s 348ms/step
# {'rmse': {0: 0.2891058211594009}, 'mae': {0: 0.23622292173385281}, 'r2': {0: -1.2961459567255107}, 'kl_divergence': {0: 0.542545285941577}, 'cosine_similarity': {0: 0.7211781880099898}, 'pearson_correlation': {0: 0.26127441010554575}, 'fid_score': {0: 1414.2269772784457}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Entertainment/public assembly'}}
# Education
# 13/13 [==============================] - 5s 382ms/step
# 13/13 [==============================] - 7s 510ms/step
# {'rmse': {0: 0.25242692020937213}, 'mae': {0: 0.20563859957827116}, 'r2': {0: -7.720065175943507}, 'kl_divergence': {0: 0.4907632153393577}, 'cosine_similarity': {0: 0.7698137761268621}, 'pearson_correlation': {0: 0.3811427492569803}, 'fid_score': {0: 1070.5874075746547}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Education'}}
# Lodging/residential
# 3/3 [==============================] - 1s 384ms/step
# 3/3 [==============================] - 1s 384ms/step
# {'rmse': {0: 0.2574805966885404}, 'mae': {0: 0.2097108164471158}, 'r2': {0: -1.076869710748147}, 'kl_divergence': {0: 0.32818585935055977}, 'cosine_similarity': {0: 0.8047787887301738}, 'pearson_correlation': {0: 0.2640012138944362}, 'fid_score': {0: 1239.353016153692}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Lodging/residential'}}
# electricity
# 14/14 [==============================] - 11s 791ms/step
# 14/14 [==============================] - 6s 397ms/step
# {'rmse': {0: 0.2357477902549866}, 'mae': {0: 0.18989060763072657}, 'r2': {0: -0.8881238996086925}, 'kl_divergence': {0: 0.27045763053432936}, 'cosine_similarity': {0: 0.831462677694705}, 'pearson_correlation': {0: 0.3990792215951283}, 'fid_score': {0: 947.2538463398041}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'electricity'}}
# gas
# 3/3 [==============================] - 1s 273ms/step
# 3/3 [==============================] - 1s 276ms/step
# {'rmse': {0: 0.2903285600021344}, 'mae': {0: 0.24079494820008104}, 'r2': {0: -1.1756338220664508}, 'kl_divergence': {0: 0.8827057231799872}, 'cosine_similarity': {0: 0.6469270675211258}, 'pearson_correlation': {0: 0.41267033855623014}, 'fid_score': {0: 2328.424791174981}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'gas'}}
# chilledwater
# 7/7 [==============================] - 4s 527ms/step
# 7/7 [==============================] - 2s 348ms/step
# {'rmse': {0: 0.2802407624435158}, 'mae': {0: 0.23216193165629584}, 'r2': {0: -10.705829160941633}, 'kl_divergence': {0: 0.5562005775807527}, 'cosine_similarity': {0: 0.7407797207442166}, 'pearson_correlation': {0: 0.3254640815507167}, 'fid_score': {0: 957.759248683449}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'chilledwater'}}
# hotwater
# 3/3 [==============================] - 1s 243ms/step
# 3/3 [==============================] - 1s 237ms/step
# {'rmse': {0: 0.3028309542985531}, 'mae': {0: 0.2501763180469617}, 'r2': {0: -1.657577081365864}, 'kl_divergence': {0: 0.774663061323948}, 'cosine_similarity': {0: 0.6587657447933831}, 'pearson_correlation': {0: 0.17287337288660365}, 'fid_score': {0: 1609.6990878479087}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'hotwater'}}
# steam
# 4/4 [==============================] - 1s 333ms/step
# 4/4 [==============================] - 2s 373ms/step
# {'rmse': {0: 0.2621762871167227}, 'mae': {0: 0.2122222598683632}, 'r2': {0: -7.572135647441692}, 'kl_divergence': {0: 0.5357341561131329}, 'cosine_similarity': {0: 0.7453395703097058}, 'pearson_correlation': {0: 0.27422029234714745}, 'fid_score': {0: 1479.0685345928168}, 'model': {0: 'CVAE_mse'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'steam'}}
# 51.49783804108846
# 3/3 [==============================] - 3s 363ms/step
# 3/3 [==============================] - 1s 362ms/step
# {'rmse': {0: 0.2749708894984396}, 'mae': {0: 0.1939752942920272}, 'r2': {0: -1.026531600021566}, 'kl_divergence': {0: 1.7058105254194333}, 'cosine_similarity': {0: 0.5605905319449851}, 'pearson_correlation': {0: 0.30300243598211696}, 'fid_score': {0: 1988.7768322115085}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 51.49783804108846}}
# 38.9035039800032
# 5/5 [==============================] - 2s 324ms/step
# 5/5 [==============================] - 2s 322ms/step
# {'rmse': {0: 0.2713546100857023}, 'mae': {0: 0.21890195425959555}, 'r2': {0: -1.2385763305885533}, 'kl_divergence': {0: 0.40689477184425543}, 'cosine_similarity': {0: 0.7834304523203316}, 'pearson_correlation': {0: 0.18448279470785137}, 'fid_score': {0: 994.9557309622377}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 38.9035039800032}}
# 37.87190340000004
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 346ms/step
# {'rmse': {0: 0.2590829173017708}, 'mae': {0: 0.2097180594625526}, 'r2': {0: -0.9405668128317344}, 'kl_divergence': {0: 0.33555134780270207}, 'cosine_similarity': {0: 0.8178696759162934}, 'pearson_correlation': {0: 0.34228524260188614}, 'fid_score': {0: 1744.7432284000051}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 37.87190340000004}}
# 51.49984
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# {'rmse': {0: 0.274488469403822}, 'mae': {0: 0.19149773907393802}, 'r2': {0: -0.20661754655174983}, 'kl_divergence': {0: 1.3758755057663539}, 'cosine_similarity': {0: 0.6711159174061525}, 'pearson_correlation': {0: 0.48273578217004154}, 'fid_score': {0: 4012.225963538943}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 51.49984}}
# 30.26719999999989
# 5/5 [==============================] - 2s 344ms/step
# 5/5 [==============================] - 2s 342ms/step
# {'rmse': {0: 0.250154574050949}, 'mae': {0: 0.19982945600290306}, 'r2': {0: -0.9757883116593146}, 'kl_divergence': {0: 0.6194976711831757}, 'cosine_similarity': {0: 0.8138836262365284}, 'pearson_correlation': {0: 0.41447660834996314}, 'fid_score': {0: 1125.3975686916583}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 30.26719999999989}}
# 33.42442530000004
# 5/5 [==============================] - 2s 349ms/step
# 5/5 [==============================] - 2s 342ms/step
# {'rmse': {0: 0.27047373498992044}, 'mae': {0: 0.21193945741430198}, 'r2': {0: -7.441513184722954}, 'kl_divergence': {0: 0.9878809280786274}, 'cosine_similarity': {0: 0.7436907754674213}, 'pearson_correlation': {0: 0.35407705120189753}, 'fid_score': {0: 1324.7889586328838}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 33.42442530000004}}
# 44.97878184783975
# 5/5 [==============================] - 2s 324ms/step
# 5/5 [==============================] - 2s 506ms/step
# {'rmse': {0: 0.25702869522970423}, 'mae': {0: 0.19420313401662825}, 'r2': {0: -0.47900292018267027}, 'kl_divergence': {0: 0.7685669078486258}, 'cosine_similarity': {0: 0.744817705626902}, 'pearson_correlation': {0: 0.42848299662622874}, 'fid_score': {0: 1199.9660588054517}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 44.97878184783975}}
# 37.406733422173815
# 4/4 [==============================] - 2s 492ms/step
# 4/4 [==============================] - 2s 581ms/step
# {'rmse': {0: 0.28326544534615206}, 'mae': {0: 0.2256101939871999}, 'r2': {0: -1.3044654111463034}, 'kl_divergence': {0: 0.772702127756652}, 'cosine_similarity': {0: 0.7412157484623562}, 'pearson_correlation': {0: 0.2303664831362693}, 'fid_score': {0: 966.8302471874335}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 37.406733422173815}}
# 45.4215
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 459ms/step
# {'rmse': {0: 0.26322805330812193}, 'mae': {0: 0.19523602178382005}, 'r2': {0: -0.34529689127056357}, 'kl_divergence': {0: 1.261574293333127}, 'cosine_similarity': {0: 0.7177512362437466}, 'pearson_correlation': {0: 0.44871321200124586}, 'fid_score': {0: 1821.3164063963754}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 45.4215}}
# 53.34979999999997
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 1s 508ms/step
# {'rmse': {0: 0.27800239951603184}, 'mae': {0: 0.20921007096729116}, 'r2': {0: -0.7878563157337432}, 'kl_divergence': {0: 1.65317161446279}, 'cosine_similarity': {0: 0.658541084285087}, 'pearson_correlation': {0: 0.3556061943420586}, 'fid_score': {0: 1904.7710431905102}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 53.34979999999997}}
# 51.51878965384613
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 34ms/step
# {'rmse': {0: 0.2814295699785048}, 'mae': {0: 0.230862619224039}, 'r2': {0: -1.6817353023346968}, 'kl_divergence': {0: 0.8989409864698569}, 'cosine_similarity': {0: 0.7488109146823394}, 'pearson_correlation': {0: 0.32244666009900824}, 'fid_score': {0: 1545.1952674826698}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 51.51878965384613}}
# 40.349999999999966
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 330ms/step
# {'rmse': {0: 0.23223705235465683}, 'mae': {0: 0.1817359460530256}, 'r2': {0: -19.21327123866527}, 'kl_divergence': {0: 0.7060290953568122}, 'cosine_similarity': {0: 0.7967742368460117}, 'pearson_correlation': {0: 0.4412351549376143}, 'fid_score': {0: 1655.8297261867788}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 40.349999999999966}}
# 28.5176885788321
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 147ms/step
# {'rmse': {0: 0.3082041184432755}, 'mae': {0: 0.24942441917159763}, 'r2': {0: -2.291463566642203}, 'kl_divergence': {0: 1.2612062370256352}, 'cosine_similarity': {0: 0.6447457899460264}, 'pearson_correlation': {0: 0.17873186219587892}, 'fid_score': {0: 2971.196446355262}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 28.5176885788321}}
# Office
# 7/7 [==============================] - 3s 373ms/step
# 7/7 [==============================] - 3s 375ms/step
# {'rmse': {0: 0.2631095779849787}, 'mae': {0: 0.20255181584764462}, 'r2': {0: -0.8259409808130587}, 'kl_divergence': {0: 0.8186113304353753}, 'cosine_similarity': {0: 0.7492661326976672}, 'pearson_correlation': {0: 0.3822774832125423}, 'fid_score': {0: 1074.4022495719494}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Office'}}
# Public services
# 3/3 [==============================] - 1s 282ms/step
# 3/3 [==============================] - 1s 281ms/step
# {'rmse': {0: 0.27706784210030033}, 'mae': {0: 0.22532741821869945}, 'r2': {0: -1.2036802528112467}, 'kl_divergence': {0: 0.4615188448940041}, 'cosine_similarity': {0: 0.7880084917656814}, 'pearson_correlation': {0: 0.19457249638230822}, 'fid_score': {0: 1120.4518721195925}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Public services'}}
# Entertainment/public assembly
# 4/4 [==============================] - 1s 347ms/step
# 4/4 [==============================] - 3s 592ms/step
# {'rmse': {0: 0.28480339626183354}, 'mae': {0: 0.22079478478955314}, 'r2': {0: -1.1998372697841395}, 'kl_divergence': {0: 0.9952217729167122}, 'cosine_similarity': {0: 0.6809133478724017}, 'pearson_correlation': {0: 0.2034850802131542}, 'fid_score': {0: 1156.7232163323833}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Entertainment/public assembly'}}
# Education
# 13/13 [==============================] - 6s 453ms/step
# 13/13 [==============================] - 5s 386ms/step
# {'rmse': {0: 0.26319881956226443}, 'mae': {0: 0.20377530351910983}, 'r2': {0: -4.370674544583805}, 'kl_divergence': {0: 0.9601795530339178}, 'cosine_similarity': {0: 0.7352615420995775}, 'pearson_correlation': {0: 0.3673569418262635}, 'fid_score': {0: 985.1896578888527}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Education'}}
# Lodging/residential
# 3/3 [==============================] - 1s 389ms/step
# 3/3 [==============================] - 2s 610ms/step
# {'rmse': {0: 0.2615789106782013}, 'mae': {0: 0.20910046179531727}, 'r2': {0: -1.0966019245847347}, 'kl_divergence': {0: 0.5910757137542079}, 'cosine_similarity': {0: 0.792974563581132}, 'pearson_correlation': {0: 0.3178383310251762}, 'fid_score': {0: 1364.708694875441}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Lodging/residential'}}
# electricity
# 14/14 [==============================] - 7s 482ms/step
# 14/14 [==============================] - 7s 515ms/step
# {'rmse': {0: 0.25928226197878407}, 'mae': {0: 0.2086461274488696}, 'r2': {0: -1.2309181715800217}, 'kl_divergence': {0: 0.43670815181802053}, 'cosine_similarity': {0: 0.7963026612015843}, 'pearson_correlation': {0: 0.2737072592650247}, 'fid_score': {0: 880.365833328442}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'electricity'}}
# gas
# 3/3 [==============================] - 1s 276ms/step
# 3/3 [==============================] - 1s 278ms/step
# {'rmse': {0: 0.2767552566126047}, 'mae': {0: 0.1886974334419275}, 'r2': {0: -0.8424981509819834}, 'kl_divergence': {0: 2.0949497524879273}, 'cosine_similarity': {0: 0.5450134894444736}, 'pearson_correlation': {0: 0.315765352371719}, 'fid_score': {0: 2096.286149523914}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'gas'}}
# chilledwater
# 7/7 [==============================] - 2s 347ms/step
# 7/7 [==============================] - 3s 393ms/step
# {'rmse': {0: 0.2684608420870283}, 'mae': {0: 0.20342585171407943}, 'r2': {0: -5.044724351694658}, 'kl_divergence': {0: 1.105460551622024}, 'cosine_similarity': {0: 0.7468972910711439}, 'pearson_correlation': {0: 0.48573161434576384}, 'fid_score': {0: 1099.8579700114888}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'chilledwater'}}
# hotwater
# 3/3 [==============================] - 1s 232ms/step
# 3/3 [==============================] - 1s 397ms/step
# {'rmse': {0: 0.31165567227887503}, 'mae': {0: 0.2435465823321864}, 'r2': {0: -1.8032286819522492}, 'kl_divergence': {0: 1.396211685668943}, 'cosine_similarity': {0: 0.6173089466531513}, 'pearson_correlation': {0: 0.20732485560340305}, 'fid_score': {0: 1496.4771957193923}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'hotwater'}}
# steam
# 4/4 [==============================] - 2s 597ms/step
# 4/4 [==============================] - 2s 390ms/step
# {'rmse': {0: 0.26104829614920505}, 'mae': {0: 0.20515978980465074}, 'r2': {0: -4.763090086733152}, 'kl_divergence': {0: 0.8864854908102094}, 'cosine_similarity': {0: 0.7249151958505679}, 'pearson_correlation': {0: 0.3636776808001851}, 'fid_score': {0: 1291.7721406918636}, 'model': {0: 'CGAN'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'steam'}}
# 51.49783804108846
# 3/3 [==============================] - 3s 359ms/step
# 3/3 [==============================] - 1s 361ms/step
# {'rmse': {0: 0.30737120240934734}, 'mae': {0: 0.25796732831340663}, 'r2': {0: -1.721560176410008}, 'kl_divergence': {0: 0.8459114137724728}, 'cosine_similarity': {0: 0.644181588319779}, 'pearson_correlation': {0: 0.40003177145400376}, 'fid_score': {0: 1738.2189188890043}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 51.49783804108846}}
# 38.9035039800032
# 5/5 [==============================] - 2s 322ms/step
# 5/5 [==============================] - 3s 558ms/step
# {'rmse': {0: 0.23709667720081898}, 'mae': {0: 0.19143764281492673}, 'r2': {0: -0.7130792245292018}, 'kl_divergence': {0: 0.25345037737987264}, 'cosine_similarity': {0: 0.8268541545147318}, 'pearson_correlation': {0: 0.2944443970892995}, 'fid_score': {0: 863.0463078946761}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 38.9035039800032}}
# 37.87190340000004
# 1/1 [==============================] - 0s 466ms/step
# 1/1 [==============================] - 1s 642ms/step
# {'rmse': {0: 0.20123525818312193}, 'mae': {0: 0.16281846111959677}, 'r2': {0: -0.22024830469233936}, 'kl_divergence': {0: 0.17636557764704208}, 'cosine_similarity': {0: 0.8813184512623389}, 'pearson_correlation': {0: 0.5478336217663629}, 'fid_score': {0: 1329.9130432147545}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 37.87190340000004}}
# 51.49984
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 97ms/step
# {'rmse': {0: 0.34639837969889264}, 'mae': {0: 0.2834147762258278}, 'r2': {0: -1.2297840860286633}, 'kl_divergence': {0: 0.9013323021370004}, 'cosine_similarity': {0: 0.6659601838096363}, 'pearson_correlation': {0: 0.42050110749755554}, 'fid_score': {0: 3246.153416552931}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 51.49984}}
# 30.26719999999989
# 5/5 [==============================] - 2s 348ms/step
# 5/5 [==============================] - 2s 349ms/step
# {'rmse': {0: 0.19363614186920725}, 'mae': {0: 0.15725172412654864}, 'r2': {0: -0.24656780019565666}, 'kl_divergence': {0: 0.17755395811202254}, 'cosine_similarity': {0: 0.8962475939672059}, 'pearson_correlation': {0: 0.5953808252462488}, 'fid_score': {0: 798.2436583150518}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 30.26719999999989}}
# 33.42442530000004
# 5/5 [==============================] - 2s 386ms/step
# 5/5 [==============================] - 3s 591ms/step
# {'rmse': {0: 0.26967109007382645}, 'mae': {0: 0.22277122733316235}, 'r2': {0: -12.340982889671718}, 'kl_divergence': {0: 0.5062619674595551}, 'cosine_similarity': {0: 0.7704702472388638}, 'pearson_correlation': {0: 0.34314776144080283}, 'fid_score': {0: 900.7605254493579}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 33.42442530000004}}
# 44.97878184783975
# 5/5 [==============================] - 2s 325ms/step
# 5/5 [==============================] - 2s 324ms/step
# {'rmse': {0: 0.23768770980034976}, 'mae': {0: 0.19485961217925035}, 'r2': {0: -0.3062137920791741}, 'kl_divergence': {0: 0.4001288008205139}, 'cosine_similarity': {0: 0.818467119487596}, 'pearson_correlation': {0: 0.5707682669924017}, 'fid_score': {0: 838.5025294190406}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 44.97878184783975}}
# 37.406733422173815
# 4/4 [==============================] - 1s 345ms/step
# 4/4 [==============================] - 1s 346ms/step
# {'rmse': {0: 0.24874953954905418}, 'mae': {0: 0.20307229807472602}, 'r2': {0: -0.8068478457046182}, 'kl_divergence': {0: 0.32028824024234576}, 'cosine_similarity': {0: 0.8187425344880509}, 'pearson_correlation': {0: 0.34846737461685046}, 'fid_score': {0: 851.6106217058109}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 37.406733422173815}}
# 45.4215
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 246ms/step
# {'rmse': {0: 0.2856974579412284}, 'mae': {0: 0.2366934273040483}, 'r2': {0: -0.6124724561677621}, 'kl_divergence': {0: 0.5441039080784887}, 'cosine_similarity': {0: 0.7361568917466096}, 'pearson_correlation': {0: 0.3360149202603354}, 'fid_score': {0: 1761.5228076453577}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 45.4215}}
# 53.34979999999997
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 300ms/step
# {'rmse': {0: 0.2506221320860164}, 'mae': {0: 0.20482565044076625}, 'r2': {0: -0.5180286367034033}, 'kl_divergence': {0: 0.4738023994802694}, 'cosine_similarity': {0: 0.7915460522266055}, 'pearson_correlation': {0: 0.47588224369220156}, 'fid_score': {0: 1491.92774432069}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 53.34979999999997}}
# 51.51878965384613
# 2/2 [==============================] - 1s 58ms/step
# 2/2 [==============================] - 1s 68ms/step
# {'rmse': {0: 0.2210877309724833}, 'mae': {0: 0.1804444949416091}, 'r2': {0: -0.6129675607874585}, 'kl_divergence': {0: 0.23125470548962135}, 'cosine_similarity': {0: 0.8683660541829532}, 'pearson_correlation': {0: 0.45464780062239923}, 'fid_score': {0: 1225.6584376868366}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 51.51878965384613}}
# 40.349999999999966
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 1s 560ms/step
# {'rmse': {0: 0.25741404800658474}, 'mae': {0: 0.21380007554068534}, 'r2': {0: -34.8257625592575}, 'kl_divergence': {0: 0.6582752354039836}, 'cosine_similarity': {0: 0.783954310481069}, 'pearson_correlation': {0: 0.3511154630691582}, 'fid_score': {0: 1768.8809152891893}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 40.349999999999966}}
# 28.5176885788321
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 144ms/step
# {'rmse': {0: 0.24430052823102194}, 'mae': {0: 0.19887424590531608}, 'r2': {0: -1.036429382725555}, 'kl_divergence': {0: 0.3195552767295563}, 'cosine_similarity': {0: 0.8169796809574252}, 'pearson_correlation': {0: 0.25997781763668937}, 'fid_score': {0: 1821.3748818505544}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'lat'}, 'agg_item': {0: 28.5176885788321}}
# Office
# 7/7 [==============================] - 3s 374ms/step
# 7/7 [==============================] - 3s 422ms/step
# {'rmse': {0: 0.2411026343781332}, 'mae': {0: 0.19634823229065398}, 'r2': {0: -0.5436947001785406}, 'kl_divergence': {0: 0.3774799019622146}, 'cosine_similarity': {0: 0.8175518251514635}, 'pearson_correlation': {0: 0.4743131670210176}, 'fid_score': {0: 760.4498578482426}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Office'}}
# Public services
# 3/3 [==============================] - 1s 276ms/step
# 3/3 [==============================] - 1s 278ms/step
# {'rmse': {0: 0.2442872134657069}, 'mae': {0: 0.1979124348696815}, 'r2': {0: -0.6472428258650621}, 'kl_divergence': {0: 0.26671493459368445}, 'cosine_similarity': {0: 0.8296926719603883}, 'pearson_correlation': {0: 0.30062941366278106}, 'fid_score': {0: 1033.1389617248094}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Public services'}}
# Entertainment/public assembly
# 4/4 [==============================] - 1s 345ms/step
# 4/4 [==============================] - 1s 347ms/step
# {'rmse': {0: 0.27505048540708826}, 'mae': {0: 0.22825316569156412}, 'r2': {0: -1.1516544643437963}, 'kl_divergence': {0: 0.4699119533868312}, 'cosine_similarity': {0: 0.7608149536343298}, 'pearson_correlation': {0: 0.35314926415312325}, 'fid_score': {0: 935.2113086593902}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Entertainment/public assembly'}}
# Education
# 13/13 [==============================] - 5s 386ms/step
# 13/13 [==============================] - 7s 518ms/step
# {'rmse': {0: 0.24413022238254387}, 'mae': {0: 0.2010473565336186}, 'r2': {0: -6.808082928291118}, 'kl_divergence': {0: 0.43948734087968483}, 'cosine_similarity': {0: 0.7986656370684319}, 'pearson_correlation': {0: 0.44684647881082507}, 'fid_score': {0: 684.7376649795921}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Education'}}
# Lodging/residential
# 3/3 [==============================] - 1s 386ms/step
# 3/3 [==============================] - 1s 389ms/step
# {'rmse': {0: 0.22014728266846278}, 'mae': {0: 0.1788034307385719}, 'r2': {0: -0.539814810295275}, 'kl_divergence': {0: 0.2539078160711185}, 'cosine_similarity': {0: 0.8535589747256922}, 'pearson_correlation': {0: 0.4526617611087535}, 'fid_score': {0: 939.6180536315533}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'building_type'}, 'agg_item': {0: 'Lodging/residential'}}
# electricity
# 14/14 [==============================] - 7s 510ms/step
# 14/14 [==============================] - 6s 396ms/step
# {'rmse': {0: 0.2296822385868439}, 'mae': {0: 0.18661957885896205}, 'r2': {0: -0.794681890272583}, 'kl_divergence': {0: 0.23510433899619335}, 'cosine_similarity': {0: 0.8474995645279993}, 'pearson_correlation': {0: 0.3868932180331087}, 'fid_score': {0: 612.8684890363236}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'electricity'}}
# gas
# 3/3 [==============================] - 1s 269ms/step
# 3/3 [==============================] - 1s 285ms/step
# {'rmse': {0: 0.3197372713283175}, 'mae': {0: 0.26794610441890493}, 'r2': {0: -1.601892533234415}, 'kl_divergence': {0: 0.9233805540681966}, 'cosine_similarity': {0: 0.6312532331522022}, 'pearson_correlation': {0: 0.3795217365263635}, 'fid_score': {0: 1674.711798721759}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'gas'}}
# chilledwater
# 7/7 [==============================] - 3s 488ms/step
# 7/7 [==============================] - 3s 349ms/step
# {'rmse': {0: 0.2404808123058772}, 'mae': {0: 0.19719823800233052}, 'r2': {0: -8.303999962862461}, 'kl_divergence': {0: 0.4244933088629093}, 'cosine_similarity': {0: 0.8206540463895285}, 'pearson_correlation': {0: 0.5824054924644055}, 'fid_score': {0: 669.3464167478905}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'chilledwater'}}
# hotwater
# 3/3 [==============================] - 1s 231ms/step
# 3/3 [==============================] - 1s 233ms/step
# {'rmse': {0: 0.2964770473213233}, 'mae': {0: 0.24846624505940978}, 'r2': {0: -1.640298832299604}, 'kl_divergence': {0: 0.7098238615549047}, 'cosine_similarity': {0: 0.6846450256921545}, 'pearson_correlation': {0: 0.2531139864344719}, 'fid_score': {0: 1275.897124250493}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'hotwater'}}
# steam
# 4/4 [==============================] - 1s 336ms/step
# 4/4 [==============================] - 1s 338ms/step
# {'rmse': {0: 0.2318613400186942}, 'mae': {0: 0.19012388635155736}, 'r2': {0: -7.666973496875632}, 'kl_divergence': {0: 0.43454283191792215}, 'cosine_similarity': {0: 0.8100401416062112}, 'pearson_correlation': {0: 0.469417253839239}, 'fid_score': {0: 1116.9535659969624}, 'model': {0: 'diffusion_model'}, 'agg_col': {0: 'meter_type'}, 'agg_item': {0: 'steam'}}

# %%
df_metrics = pd.concat(df_metrics, ignore_index=True)
df_metrics
# Out:
#         rmse       mae        r2 kl_divergence cosine_similarity  \
# 0   0.281076  0.229512  -1.29141      0.805132          0.665435
# 1   0.243607  0.194226 -0.846401      0.285924          0.812821
# 2   0.224466  0.181437 -0.484201      0.225437          0.855348
# 3   0.311083  0.263765 -0.780368      1.005591          0.618827
# 4   0.238333  0.194005 -0.799944      0.290366          0.822118
# ..       ...       ...       ...           ...               ...
# 64  0.229682   0.18662 -0.794682      0.235104            0.8475
# 65  0.319737  0.267946 -1.601893      0.923381          0.631253
# 66  0.240481  0.197198    -8.304      0.424493          0.820654
# 67  0.296477  0.248466 -1.640299      0.709824          0.684645
# 68  0.231861  0.190124 -7.666973      0.434543           0.81004
#
#    pearson_correlation    fid_score            model     agg_col      agg_item
# 0             0.451182   2239.65718         CVAE_mse         lat     51.497838
# 1             0.320234  1130.796505         CVAE_mse         lat     38.903504
# 2             0.513794  1423.362447         CVAE_mse         lat     37.871903
# 3             0.271676   4184.53405         CVAE_mse         lat      51.49984
# 4             0.344905  1135.184288         CVAE_mse         lat       30.2672
# ..                 ...          ...              ...         ...           ...
# 64            0.386893   612.868489  diffusion_model  meter_type   electricity
# 65            0.379522  1674.711799  diffusion_model  meter_type           gas
# 66            0.582405   669.346417  diffusion_model  meter_type  chilledwater
# 67            0.253114  1275.897124  diffusion_model  meter_type      hotwater
# 68            0.469417  1116.953566  diffusion_model  meter_type         steam
#
# [69 rows x 10 columns]

# %%
df_metrics.pivot_table(index='model',values=['fid_score','pearson_correlation','mae','rmse','kl_divergence'])
# Out:
#                    fid_score  kl_divergence       mae  pearson_correlation  \
# model
# CGAN             1557.488194       0.978266  0.209703             0.330364
# CVAE_mse         1537.834360       0.505030  0.215926             0.343358
# diffusion_model  1232.119437       0.449701  0.208737             0.412920
#
#                      rmse
# model
# CGAN             0.270908
# CVAE_mse         0.263976
# diffusion_model  0.254084

# %%
generation_path = "./evaluations"
df_metrics.to_csv(os.path.join(generation_path, 'updated_All_model_metrics_agg_by_meta_168x168.csv'),index=False)
